# %% [markdown]
# <a href="https://colab.research.google.com/github/iPedroV/20114290135-Probabilidade-e-Estatistica/blob/master/Lista_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina: Probabilidade e Estatística
#Aluno: Pedro Vitor da Costa Silva
#Turma: OADSNM1B
#Lista 6

#Questão 1

'''import pandas as pd
dados = {"Matemática":[60, 58, 73, 51, 54, 75, 48, 72, 75, 83, 62, 52],
         "Música":[80, 62, 70, 83, 62, 92, 79, 88, 54, 82, 64, 69]}
x = pd.DataFrame(dados, columns = ["Matemática", "Música"])
Corr = x.corr()
print(Corr)'''

#Questão 2

''' Que indica uma correlação desprezível. '''

#Questão 3

'''import pandas as pd
dados1 = {"Ano_Serviço":[2, 3, 4, 5, 4, 6, 7, 8, 8, 10],
         "Num_Clientes":[48, 50, 56, 52, 43, 60, 62, 58, 64, 72]}
z = pd.DataFrame(dados1, columns = ["Ano_Serviço", "Num_Clientes"])
Correl = z.corr()
print(Correl)
print("\n\nComo o coeficiente de correlação está entre 0.7 a 0.9, isso indica uma correlação forte.")'''

#Questão 4

'''import pandas as dp
dados2 = {"X":[12, 16, 18, 20, 28, 30, 40, 48, 50, 54],
          "Y":[7.2, 7.4, 7.0, 6.5, 6.6, 6.7, 6.0, 5.6, 6.0, 5.5]}
w = dp.DataFrame(dados2, columns = ["X", "Y"])
Cor = w.corr()
print(Cor)'''

#Questão 5 - PS: Professor eu não consegui completar.
#Os valores da média  e do desvio padrão estavam se repetindo em todos os conjuntos.

'''import pandas as ab
import statistics
print("Conjunto 1\n")
Conj1 = {"X":[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
         "Y":[8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]}
a = ab.DataFrame(Conj1, columns = ["X", "Y"])
Correl1 = a.corr()
print(Correl1,"\n") #B - Coeficiente de correlação
MedAritmSimples = statistics.mean(Conj1["X"]) #A - Média Aritmética Simples
print("A média simples  de X é: ", MedAritmSimples)
MedAritmSimples = statistics.mean(Conj1["Y"]) #A - Média Aritmética Simples
print("A média simples  de Y é: ", round(MedAritmSimples,2))
DesvPad = statistics.stdev(Conj1["X"]) # A - Desvio Padrão
print("O desvio padrão de X é: ", round(DesvPad,2))
DesvPad = statistics.stdev(Conj1["Y"]) # A - Desvio Padrão
print("O desvio padrão de Y é: ", round(DesvPad,2))

import statistics
import pandas as bc
print("\n\nConjunto 2\n")
Conj2 = {"X":[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
         "Y":[9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]}
b = bc.DataFrame(Conj2, columns = ["X", "Y"])
Correl2 = b.corr()
print(Correl2,"\n") #B - Coeficiente de correlação
MedArit = statistics.mean(Conj2["X"]) #A - Média Aritmética Simples
print("A média simples  de X é: ", MedArit)
MedArit = statistics.mean(Conj2["Y"]) #A - Média Aritmética Simples
print("A média simples  de Y é: ", round(MedArit,2))
DesPad = statistics.stdev(Conj2["X"]) # A - Desvio Padrão
print("O desvio padrão de X é: ", round(DesPad,2))
DesPad = statistics.stdev(Conj2["Y"]) # A - Desvio Padrão
print("O desvio padrão de Y é: ", round(DesPad,2))

import statistics
import pandas as cd
print("\n\nConjunto 3\n")
Conj3 = {"X":[10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
         "Y":[7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]}
c = cd.DataFrame(Conj3, columns = ["X", "Y"])
Correl3 = c.corr()
print(Correl3,"\n") #B - Coeficiente de correlação
MedArit = statistics.mean(Conj3["X"]) #A - Média Aritmética Simples
print("A média simples  de X é: ", MedArit)
MedArit = statistics.mean(Conj3["Y"]) #A - Média Aritmética Simples
print("A média simples  de Y é: ", round(MedArit,2))
DesPad = statistics.stdev(Conj3["X"]) # A - Desvio Padrão
print("O desvio padrão de X é: ", round(DesPad,2))
DesPad = statistics.stdev(Conj3["Y"]) # A - Desvio Padrão
print("O desvio padrão de Y é: ", round(DesPad,2))

import statistics
import pandas as de
print("\n\nConjunto 4\n")
Conj4 = {"X":[8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8],
         "Y":[6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]}
d = de.DataFrame(Conj4, columns = ["X", "Y"])
Correl4 = d.corr()
print(Correl4,"\n") #B - Coeficiente de correlação
MedArit = statistics.mean(Conj4["X"]) #A - Média Aritmética Simples
print("A média simples  de X é: ", MedArit)
MedArit = statistics.mean(Conj4["Y"]) #A - Média Aritmética Simples
print("A média simples  de Y é: ", round(MedArit,2))
DesPad = statistics.stdev(Conj4["X"]) # A - Desvio Padrão
print("O desvio padrão de X é: ", round(DesPad,2))
DesPad = statistics.stdev(Conj4["Y"]) # A - Desvio Padrão
print("O desvio padrão de Y é: ", round(DesPad,2))'''

#Questão 6

'''import pandas as df
import seaborn as sn
import matplotlib.pyplot as plt
print("Tabela\n")
Conj4 = {"prod":[100, 102, 105, 108, 112, 120],
         "alim":[4, 5, 1, 3, 6, 2],
         "exer":[1, 3, 2, 4, 5, 6],
         "rodi":[3, 1, 2, 6, 4, 5]}
x = df.DataFrame(Conj4, columns = ["alim", "exer", "rodi"])
Correla = x.corr()
print(Correla)
print("\nConfirmação da impressão visual dos diagramas:\n")
sn.heatmap(Correla, annot=True)
plt.show()'''
