# %% [markdown]
# <a href="https://colab.research.google.com/github/iPedroV/20114290135-Probabilidade-e-Estatistica/blob/master/Lista_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina: Probabilidade e Estatística
#Aluno: Pedro Vitor da Costa Silva
#Lista 4

#Questão 1

'''lado1 = int(input("Digite a quantidade de lados: "))
lado2 = float(input("Digite a medida dos lados: "))
if lado1 == 3:
  area = lado2 ** 2 * 3 ** (1/2) / 4
  area = round(area,2)
  print("É um TRIÂNGULO e o valor da sua área é: " ,area,"cm²")
elif  lado1 == 4:
  area = lado2 ** 2
  area = round(area,2)
  print("É um QUADRADO e o valor da sua área é: ",area,"cm²")
elif lado1 == 5:
  print("teste")
else:
  print("Insira uma quantidade de lados entre 3 e 5!")
lado1 = int(input("Digite a quantidade de lados: "))
lado2 = float(input("Digite a medida dos lados: "))
if lado1 == 3:
  area = lado2 ** 2 * 3 ** (1/2) / 4
  area = round(area,2)
  print("É um TRIÂNGULO e o valor da sua área é: " ,area,"cm²")
elif  lado1 == 4:
  area = lado2 ** 2
  area = round(area,2)
  print("É um QUADRADO e o valor da sua área é: ",area,"cm²")
elif lado1 == 5:
  print("teste")'''

#Questão 2

'''lado1 = int(input("Digite a quantidade de lados: "))
lado2 = float(input("Digite a medida dos lados: "))
if lado1 == 3:
  area = lado2 ** 2 * 3 ** (1/2) / 4
  area = round(area,2)
  print("É um TRIÂNGULO e o valor da sua área é: " ,area,"cm²")
elif  lado1 == 4:
  area = lado2 ** 2
  area = round(area,2)
  print("É um QUADRADO e o valor da sua área é: ",area,"cm²")
elif lado1 == 5:
  print("teste")
else:
  if lado1 < 3:
    print("NÃO É UM POLÍGNO")
  elif lado1 >= 5:
    print("POLÍGNO NÃO IDENTIFICADO")'''

#Questão 3

'''n1 = float(input("Digite o primeiro valor: "))
n2 = float(input("Digite o segundo valor: "))
n3 = float(input("Digite o terceiro valor: "))

if n1 > n2 and n1 > n3:
  maior = n1
if n2 > n1 and n2 > n3:
  maior = n2
if n3 > n1 and n3 > n2:
 maior = n3
print("O maior digitado é: ",maior)'''

#Questão 4

'''l1 = int(input("Lado 1: "))
l2 = int(input("Lado 2: "))
l3 = int(input("Lado 3: "))

if l1 > (l2+l3) or l2 > (l1+l3) or l3 > (l1+l2):
	print ("Não é um triângulo")
elif l1 == l2 == l3:
	print ("Triângulo Equilátero")
elif l1 == l2 or l1 == l3 or l2 == l3:
	print ("Triângulo Isósceles")
else:
	print ("Triângulo Escaleno")'''

#Questão 5

'''a1 = float(input("Digite o valor do primeiro ângulo: "))
a2 = float(input("Digite o valor do segundo ângulo: "))
a3 = float(input("Digite o valor do terceiroo ângulo: "))

if a1 == 90 or a2 == 90 or a3 == 90:
  print("É um trângulo retângulo")
elif a1 > 90 and a2 > 90 and a3 > 90:
   print("É um trângulo agudo")
else:
  print("É um trângulo obtuso")'''

#Questão 6

'''n = int(input("Digite um número: "))
x = 0
for x in range(x, n+1):
  print(x)'''

#Questão 7

'''n = int(input("Insira um número entre 1 e 4: "))
if n<1 or n>4:
  while True:
    print("entrada inválida!")
    n = int(input("Insira um número entre 1 e 4: "))
    if n>=1 and n<=4:
      break
if n>= 1 or n<=4:
  print(n)'''

#Questão 8

'''n = []
while n!=0:
  n = int(input('\n\nDigite um número inteiro: '))
  n1.append(n)
  print("Todos os números digitados até agora: ",n1)
  maior = max(n1)
  print("O maior digitado até o momento foi o número:",maior)'''

#Questão 9

'''num = int(input("introduza um número: "))
u = num // 1 % 10
d = num // 10 % 10
c = num // 100 % 10
m = num // 1000 % 10
print("Unidade: {}".format(u))
print("Dezena:  {}".format(d))
print("Centena: {}".format(c))
print("Milhar:  {}".format(m))'''
